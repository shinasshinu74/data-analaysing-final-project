# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the file 
df = pd.read_csv(r"C:\Users\hp\OneDrive\Documents\pts or vds for data analyse\archive.zip")

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.head() #first 5
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# ...

# %%
df.tail() #last 5
# Out:
#        employee_id   department     region         education gender  \
# 23485        53478        Legal   region_2   Below Secondary      m
# 23486        25600   Technology  region_25        Bachelor's      m
# 23487        45409           HR  region_16        Bachelor's      f
# 23488         1186  Procurement  region_31        Bachelor's      m
# 23489         5973   Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 23485            sourcing                1   24                   3.0
# 23486            sourcing                1   31                   3.0
# 23487            sourcing                1   26                   4.0
# 23488            sourcing                3   27                   NaN
# 23489               other                3   40                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# ...

# %%
df.info()
df.describe()
#checking information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             22456 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  21678 non-null  float64
#  9   length_of_service     23490 non-null  int64
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.3+ MB
# ...

# %%
#checking where is the non values 
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
#replaced missing values 
df['education'] = df['education'].fillna('Unknown')
df['previous_year_rating'] = df['previous_year_rating'].fillna('Unknown')

# %%
#removed duplicates
df.drop_duplicates()
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age previous_year_rating  \
# ...

# %%
#confirming that there is no wrong datatype becouse there are 13 coloumns 
#7 int 
#1 float
#5 object
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             23490 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  23490 non-null  object
#  9   length_of_service     23490 non-null  int64
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: int64(7), object(6)
# memory usage: 2.3+ MB

# %%
#confirming that there is no missing valuues
df.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64

# %%
#creating bins and labels for Derived Features
bins = [0, 18, 35, 50, 100]  
labels = ['Teen', 'Young Adult', 'Middle Age', 'Old']
# Create new column AgeGroup
df['AgeGroup'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
newcol = df[['AgeGroup']]

# %%
newcol
# Out:
#           AgeGroup
# 0      Young Adult
# 1      Young Adult
# 2      Young Adult
# 3      Young Adult
# 4      Young Adult
# ...            ...
# 23485  Young Adult
# 23486  Young Adult
# 23487  Young Adult
# 23488  Young Adult
# 23489   Middle Age
#
# [23490 rows x 1 columns]

# %%
#transformation
df['gender']=df['gender'].str.upper() #uppercase the letters

# %%
df['gender']
# Out:
# 0        M
# 1        F
# 2        M
# 3        F
# 4        M
#         ..
# 23485    M
# 23486    M
# 23487    F
# 23488    M
# 23489    M
# Name: gender, Length: 23490, dtype: object

# %%
#outliers
for col in df.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(5,3))
    sns.boxplot(x=df[col])
    plt.title(f"outlier of {col}")
    plt.show()

# %% [markdown]
# #EDA & Visualizations

# %% [markdown]
# #Univariate Analysis

# %%
#histogram
#age distribution
sns.histplot(df['age'], bins=20, kde=True)
plt.title("Distribution of Employee Age")
plt.show()

# %%
#Age is mostly distributed between 28-34 years

# %%
# Department count
sns.countplot(x='department', data=df, palette='Set2')
plt.title("Employee Count per Department")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_19172\2297704535.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='department', data=df, palette='Set2')

# %%
#sales&marketing departments have higher employee counts.

# %%
# Boxplot for training score
sns.boxplot(y=df['avg_training_score'], color='orange')
plt.title("Boxplot of Avg Training Score")
plt.show()

# %%
#Training scores show some outliers
#training_score 40 is on 25%
#training_score 60 is on 50%
#training_score 99 is on 75%

# %% [markdown]
# #Bivariate Analysis

# %%
# Age vs Training Score
sns.scatterplot(x='age', y='avg_training_score', hue='gender', data=df)
plt.title("Age vs Training Score by Gender")
plt.show()

# %%
#Training score decreases with age for 20-23
#Training score increases with age for 27-53

# %%
# Department vs Training Score
sns.boxplot(x='department', y='avg_training_score', data=df, palette='Set3')
plt.title("Training Score by Department")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10124\3871332532.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='department', y='avg_training_score', data=df, palette='Set3')

# %%
#HR department and finance department show lower training score
#R&D department and analytics department show higher training scores.

# %%
# Gender distribution across departments
pd.crosstab(df['department'], df['gender']).plot(kind='bar', figsize=(8,5))
plt.title("Gender Distribution by Department")
plt.ylabel("Count")
plt.show()

# %%
#male emplyoyees are more than female employees in all department

# %% [markdown]
# #Multivariate Analysis

# %%
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])
# Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm',center=0)
plt.title("Correlation Heatmap (Numeric Columns)")
plt.show()

# %%
#length of service shows a moderate positive correlation with age

# %%
df.select_dtypes(include=['int64', 'float64'])
# Out:
#        employee_id  no_of_trainings  age  length_of_service  KPIs_met >80%  \
# 0             8724                1   24                  1              1
# 1            74430                1   31                  5              0
# 2            72255                1   31                  4              0
# 3            38562                3   31                  9              0
# 4            64486                1   30                  7              0
# ...            ...              ...  ...                ...            ...
# 23485        53478                1   24                  1              0
# 23486        25600                1   31                  7              0
# 23487        45409                1   26                  4              0
# 23488         1186                3   27                  1              0
# 23489         5973                3   40                  5              1
#
#        awards_won?  avg_training_score
# ...

# %%
# Pairplot for key variables
sns.pairplot(df[['age', 'avg_training_score', 'length_of_service']], diag_kind='kde')
plt.show()

# %% [markdown]
# #Groupby & Pivot Tables

# %%
#groupby
# Average training score by Department
dept_training = df.groupby('department')['avg_training_score'].mean()
print(dept_training)
# Out:
# department
# Analytics            84.541182
# Finance              60.322640
# HR                   50.305991
# Legal                59.575281
# Operations           60.300798
# Procurement          70.146026
# R&D                  84.413636
# Sales & Marketing    50.085988
# Technology           79.860511
# Name: avg_training_score, dtype: float64

# %%
#analytics and r&d departments are in high training score

# %%
# Pivot: Department vs Gender vs Avg Training Score
pivot_table = df.pivot_table(values='avg_training_score',
                             index='department',
                             columns='gender',
                             aggfunc='mean')
print(pivot_table)
# Out:
# gender                     F          M
# department
# Analytics          84.780269  84.515744
# Finance            60.756458  60.179268
# HR                 50.386313  50.248418
# Legal              59.936170  59.532663
# Operations         60.438641  60.203438
# Procurement        70.260486  70.052378
# R&D                84.880000  84.385542
# Sales & Marketing  49.939548  50.119825
# Technology         79.791631  79.904348

# %%
#analytics and r&d departments are in high training score and female employees have more traing score than male employees

# %% [markdown]
# #Combined Visualizations (Subplots)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

# Histogram for Age
sns.histplot(df['age'], bins=20, kde=True, ax=axes[0], color='skyblue')
axes[0].set_title("Age Distribution")

# Boxplot for Training Score
sns.boxplot(y=df['avg_training_score'], ax=axes[1], color='lightgreen')
axes[1].set_title("Training Score Boxplot")

plt.tight_layout()
plt.show()

# %%
#Subplots allow side-by-side visualization for quick comparisons. Here, we compare age distribution with training score distribution.

# %%
# Pie chart for the 'department' column
# Count the number of employees in each department
department_counts = df['department'].value_counts()

# Plot pie chart
plt.figure(figsize=(8,8))
plt.pie(department_counts, 
        labels=department_counts.index,   # Names of departments
        autopct='%1.1f%%',               # Show percentages
        startangle=140,)                  # Start angle of first slice
        
plt.title('Employee Distribution by Department')
plt.show()

# %%
#the highest number of employees are in sales&marketing
#the lowest number of employees are in legal and R&D
